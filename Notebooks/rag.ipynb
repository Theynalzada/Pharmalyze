# %% [markdown]
# ### Retrieval Augmented Generation (RAG) for Medical Science

# %%
# Importing Dependencies
import transformers
import warnings
import sys

# %%
# Filtering out potential warnings
warnings.filterwarnings(action="ignore")

# Muting transformer notifications
transformers.logging.set_verbosity_error()

# %%
# Appending the path
sys.path.append("../Scripts/")

# Loading the dependency
from generation import MedRAG

# %%
# Instantiating the RAG instance
rag=MedRAG()
# Out:
# ...
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]

# %%
# Defining the query
user_query="What is the recommended dosage of Nanoproxen for an adult patient?"

# Sending the query to RAG (LLM)
output=rag.predict(query=user_query)

# Printing the output
print(output)
# Out:
# The recommended dosage of Nanoproxen for an adult patient is 39-450 mg once daily.

# %%
# Defining the query
user_query="What established pharmacologic class (EPC) does Naproxen belong to?"

# Sending the query to RAG (LLM)
output=rag.predict(query=user_query)

# Printing the output
print(output)
# Out:
# Naproxen belongs to the nonsteroidal anti-inflammatory drug (NSAID) pharmacologic class.

# %%
# Defining the query
user_query="When was the movie Troy released?"

# Sending the query to RAG (LLM)
output=rag.predict(query=user_query)

# Printing the output
print(output)
# Out:
# I do not know the answer given context
